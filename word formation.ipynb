# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

# %%
test = ["detriment","dexterous","discretion","optimum","collaborate","resilient","venerate","zealot","ambiguous","dissident","embellish","lethargy","subsidize","estrange","euphoric","impetuous","regress","ubiquitous","diverge","solicitous","cohesive","grievous","oblivious","reticent","inquisitive","autonomy","bureaucratic","mandate","tenacious","contingency","incongruous","liability","superfluous","antipathy","idiosyncrasy","impede","austere","notorious","provocative","conspire","contrite","symmetrical","verbose","homogeneous","magnanimous","repugnant"]
result = []
# bsObj = BeautifulSoup(html.read())
# print(bsObj.h1)
# print (html.read())
for element in test:
    html = urlopen("http://dict.youdao.com/w/eng/"+element+"/#keyfrom=dict2.index") 
    bsObj = BeautifulSoup(html)
    nameList = bsObj.findAll("div", {"id":"relWordTab"}) 
    for name in nameList:
        test.append(re.sub("\s+",",",name.get_text()))
        print(name.get_text())

# %%
new = ["词根：","detriment","adj.","detrimental","不利的；有害的","adv.","detrimentally","有害地；不利地","n.","detrimental","有害的人（或物）；不受欢迎的求婚者","词根：","dexter","adj.","dexter","右侧的；幸运的","adv.","dexterously","巧妙地；敏捷地","n.","dexterity","灵巧；敏捷；机敏","词根：","discrete","adj.","discrete","离散的，不连续的","discretionary","任意的；自由决定的","discretional","任意的（等于discretionary）；自由决定的","n.","discrete","分立元件；独立部件","词根：","optimal","adj.","optimal","最佳的；最理想的","adv.","optimally","最佳；最适宜","n.","optimization","最佳化，最优化","词根：","collaborate","adj.","collaborative","合作的，协作的","n.","collaboration","合作；勾结；通敌","collaborator","[劳经]","合作者；勾结者；通敌者","collaborationism","卖国，通敌","collaborationist","通敌卖国者；协助者","词根：","resile","n.","resilience","恢复力；弹力；顺应力","resiliency","弹性；跳回","vi.","resile","弹回；恢复原状；被撤销","词根：","venerate","adj.","venerable","庄严的，值得尊敬的；珍贵的","n.","veneration","尊敬；崇拜","venerability","尊敬；庄严；历史悠久","venerator","崇拜者；尊敬者","词根：","zealot","n.","zealotry","狂热的行为；狂言；狂热","词根：","ambiguous","adv.","ambiguously","含糊不清地","词根：","embellish","n.","embellishment","装饰，修饰；润色","词根：","lethargy","adj.","lethargic","昏睡的；无生气的；泠漠的","adv.","lethargically","昏睡地；迟钝地","词根：","subsidy","adj.","subsidized","补贴的，补助的","n.","subsidy","补贴；津贴；补助金","subsidization","补助；提供津贴；奖金","v.","subsidized","资助或补助（subsidize的过去时和过去分词）","vi.","subsidise","消退；下沉；平息","vt.","subsidise","资助（等于subsidize）；给...补助金","词根：","estrange","adj.","estranged","疏远的；不和的","n.","estrangement","疏远；失和","v.","estranged","使疏远；使隔离；使离间（estrange的过去分词）","词根：","impetuous","adv.","impetuously","性急地，激烈地","n.","impetuosity","性急，冲动；冲力，猛烈","词根：","regress","adj.","regressive","回归的；后退的；退化的","n.","regression","回归；退化；逆行；复原","词根：","ubiquity","n.","ubiquity","普遍存在；到处存在","词根：","diverge","adj.","divergent","相异的，分歧的；散开的","diverging","发散的；分歧的；岔开的（等于divergent）","divaricate","分叉的","n.","divergence","分歧","divarication","分歧；分叉；意见不同；分支","divergency","分离；分歧","v.","diverging","分叉；背离（diverge的现在分词）","vi.","divagate","离题；流浪；漫游","divaricate","叉开；分歧","vt.","divaricate","使分成两叉","词根：","solicitous","adv.","solicitously","热心地，热切地","词根：","cohere","n.","cohesion","凝聚；结合；[力]","内聚力","cohesiveness","凝聚力；粘结性；内聚力","vi.","cohere","凝聚；连贯；粘着；一致","词根：","grievous","adv.","grievously","令人悲伤地；极其痛苦地","词根：","oblivion","n.","oblivion","遗忘；湮没；赦免","obliviousness","健忘；不注意","词根：","reticent","adv.","reticently","沉默地，沉默寡言地","n.","reticence","沉默寡言","词根：","inquisite","adv.","inquisitively","好问地；过分好奇地","n.","inquisition","调查；宗教法庭；审讯","inquisitiveness","好奇；爱打听别人隐私","vt.","inquisite","调查，审讯","词根：","autonomy","adj.","autonomous","自治的；自主的；自发的","autonomic","自律的；自治的","词根：","bureaucrat","adv.","bureaucratically","官僚主义地","n.","bureaucracy","官僚主义；官僚机构；官僚政治","bureaucrat","官僚；官僚主义者","bureaucratism","官僚主义；官僚作风","词根：","mandate","adj.","mandatory","强制的；托管的；命令的","managerial","[管理]","管理的；经理的","n.","mandatory","受托者（等于mandatary）","mandator","命令者；委托人，托管人","manageress","（英）女经理；（英）女管理人","mandamus","命令书；书面训令","vt.","mandamus","发训令（过去式mandamused，过去分词mandamused，现在分词mandamusing，第三人称单数mandamuses）","词根：","tenacity","adv.","tenaciously","坚持地","n.","tenacity","韧性；固执；不屈不挠；黏性","tenaciousness","固执；顽强","词根：","contingent","adj.","contingent","因情况而异的；不一定的；偶然发生的","n.","contingent","分遣队；偶然事件；分得部分","contingence","接触；相切；偶然性（等于contingency）；意外事件；可能发生的附带事件","词根：","incongruous","adv.","incongruously","不调和地","词根：","liable","adj.","liable","有责任的，有义务的；应受罚的；有…倾向的；易…的","词根：","superfluous","adv.","superfluously","过分地；过剩地","n.","superfluity","奢侈品；额外；过剩","词根：","antipathy","adj.","antipathetic","格格不入的，怀有反感的；引起反感的；讨厌的","词根：","idiosyncrasy","adj.","idiosyncratic","特质的；特殊的；异质的","词根：","impede","n.","impediment","口吃；妨碍；阻止","impedance","[电]","阻抗","词根：","austere","adv.","austerely","严格地；简朴地","n.","austerity","紧缩；朴素；苦行；严厉","词根：","notorious","adv.","notoriously","众所周知地；声名狼藉地；恶名昭彰地","n.","notoriety","恶名；声名狼藉；丑名","词根：","provoking","adj.","provoking","刺激的；令人生气的，激怒人的","n.","provocation","挑衅；激怒；挑拨","v.","provoking","激怒；挑拨；诱发（provoke的ing形式）","词根：","conspire","n.","conspiracy","阴谋；共谋；阴谋集团","词根：","contrite","adv.","contritely","懊悔地","n.","contrition","痛悔；悔悟","词根：","symmetry","adv.","symmetrically","对称地；平衡地；匀称地","n.","symmetry","对称（性）；整齐，匀称","vt.","symmetrize","使对称；使匀称；使相称","词根：","verbose","adv.","verbosely","冗长地；啰嗦地","n.","verbosity","冗长；赘言；唠叨","verbalization","以言语表现；冗长；变成动词","verboseness","冗长，罗唆","词根：","homogenize","adj.","homogenized","成为均匀分布的微粒的","adv.","homogeneously","同样地","n.","homogeneity","同质；同种；同次性（等于homogeneousness）","homoeopathy","顺势疗法；同种疗法","homogeneousness","均质性","homograft","[生物][免疫]","同种移植物","v.","homogenized","使均匀；使类同；使（牛奶、奶油等中的油脂粒）分布均匀；变均匀（homogenize的过去式）","vi.","homogenize","变均匀","vt.","homogenize","使均匀；使类同","homogenise","（英）使均匀（等于homogenize）","词根：","magnanimous","adv.","magnanimously","大度宽宏地，度量大地；高尚地","n.","magnanimity","宽宏大量；慷慨","词根：","repugn","n.","repugnance","反感；厌恶；不一致，抵触","vi.","repugn","反抗，反对","vt.","repugn","反抗；反对"]
testAgain = [""]
flag = 1
for word in new:
    if flag == 0:
        print(word)
        flag = 1
        
    else:
        if word == "词根：":
            print("## ",end="")
            flag = 0
        
        else:
            if word.encode( 'UTF-8' ).isalpha():
                htmlFirst = urlopen("https://cn.bing.com/search?q="+str(word)+"&qs=n&form=QBLHCN&sp=-1&pq=argue&sc=0-0&sk=&cvid=87F7C9CEB72D48839C9C23BC8CE5A261") 
                bsObj = BeautifulSoup(htmlFirst)
                vocabList = bsObj.findAll("span", {"class":"sb_count"}) 
                for wow in vocabList:
                    frequency = wow.get_text()
                    print("- " + word + "    " + str(frequency))
            else:
                if word == "adj." or word == "adv." or word == "n." or word == "vi." or word == "vt." or word == "v." :
                    print("#### " + word)
        
                else:
                    print("- " + word)
# Out:
# ## detriment
# #### adj.
# /anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# - detrimental    14,800,000 条结果
# - 不利的；有害的
# #### adv.
# - detrimentally    1,330,000 条结果
# - 有害地；不利地
# #### n.
# - detrimental    14,800,000 条结果
# - 有害的人（或物）；不受欢迎的求婚者
# ## dexter
# #### adj.
# - dexter    27,500,000 条结果
# - 右侧的；幸运的
# #### adv.
# - dexterously    257,000 条结果
# - 巧妙地；敏捷地
# #### n.
# - dexterity    11,000,000 条结果
# - 灵巧；敏捷；机敏
# ...
